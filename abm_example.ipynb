# %%
from BPTK_Py.bptk import bptk
bptk = bptk()

# %%
bptk.scenario_manager_factory.scenario_managers['smSimpleProjectManagement'].scenarios
# Out:
# {'base': <BPTK_Py.scenariomanager.scenario.SimulationScenario at 0x115d29c18>,
#  'scenario100': <BPTK_Py.scenariomanager.scenario.SimulationScenario at 0x115d29ef0>,
#  'scenario80': <BPTK_Py.scenariomanager.scenario.SimulationScenario at 0x115d29d30>,
#  'scenario120': <BPTK_Py.scenariomanager.scenario.SimulationScenario at 0x115d29dd8>,
#  'scenario100WithPoints': <BPTK_Py.scenariomanager.scenario.SimulationScenario at 0x115d29d68>}

# %%
bptk.plot_scenarios(
    scenario_managers=['smSimpleProjectManagement',
                       "ABMsmSimpleProjectManagement"],
    kind="area",
    scenarios=["scenarioSPM","base"],
    equations=["openTasks","closedTasks"],
    agents=["task"],
    agent_states=["open","closed"]
)

# %%
import BPTK_Py
BPTK_Py.__version__
# Out:
# '0.4.0'
