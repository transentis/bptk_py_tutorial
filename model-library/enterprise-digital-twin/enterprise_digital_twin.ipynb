# %% [markdown]
# # Enterprise Digital Twin

# %% [markdown]
# ## Introduction
# ### Agents
#
# * Consultant. Available or Busy
# * Project. acquired->ready->started->fully_staffed->completed
#
# ### Revenue
#
# * From project assignments
#
# ### Cost
#
# * Consultant Wages
# * Overhead cost

# %%
# Start BPTK and automatically read the scenarios found in the scenarios folder
# this also loads all the Python classes referenced in the scenarios, so we are immediately ready 
# to run scenarios and plot results.

from BPTK_Py.bptk import bptk 

bptk = bptk()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [1], line 7
#       1 # Start BPTK and automatically read the scenarios found in the scenarios folder
#       2 # this also loads all the Python classes referenced in the scenarios, so we are immediately ready
#       3 # to run scenarios and plot results.
#       5 from BPTK_Py.bptk import bptk
# ----> 7 bptk = bptk()
#
# File ~/git/bptk_tutorial_internal/venv/lib/python3.9/site-packages/BPTK_Py/bptk.py:157, in bptk.__init__(self, loglevel, configuration)
#     154         plt.rcParams[key] = value
#     156 self.scenario_manager_factory = ScenarioManagerFactory(self.config.configuration["set_scenario_monitor"], self.config.configuration["set_model_monitor"])
# --> 157 self.scenario_manager_factory.get_scenario_managers()
#     158 self.visualizer = visualizer(config=self.config)
#     159 self.abmrunner = HybridRunner(self.scenario_manager_factory) #TODO rename self.abmrunner to self.model_runner if still needed
#
# File ~/git/bptk_tutorial_internal/venv/lib/python3.9/site-packages/BPTK_Py/scenariomanager/scenario_manager_factory.py:165, in ScenarioManagerFactory.get_scenario_managers(self, path, scenario_managers_to_filter, scenario_manager_type)
#     163     for infile in self.scenario_files:
#     164         if not os.path.isdir(infile):
# --> 165             self.__readScenario(filename=infile)
#     167     log("[INFO] Successfully loaded all scenarios!")
#     169 scenario_managers = self.scenario_managers
#
# File ~/git/bptk_tutorial_internal/venv/lib/python3.9/site-packages/BPTK_Py/scenariomanager/scenario_manager_factory.py:95, in ScenarioManagerFactory.__readScenario(self, filename)
#      91 if scenario_manager_name not in self.scenario_managers:
#      92     self.scenario_managers[scenario_manager_name] = ScenarioManagerHybrid(
#      93         model_dictionary[scenario_manager_name],
#      94         scenario_manager_name, model=model)
# ---> 95     self.scenario_managers[scenario_manager_name].instantiate_model()
#      96 else:
#      97     self.scenario_managers[scenario_manager_name].add_scenarios(model_dictionary[scenario_manager_name]["scenarios"])
#
# File ~/git/bptk_tutorial_internal/venv/lib/python3.9/site-packages/BPTK_Py/scenariomanager/scenario_manager_hybrid.py:99, in ScenarioManagerHybrid.instantiate_model(self, scenario_dictionary, reset)
#      94     return
#      96 scenario = scenario_class(name=scenarioName, scheduler=SimultaneousScheduler(),
#      97                           data_collector=DataCollector())
# ---> 99 scenario.instantiate_model()
#     101 scenario.configure(configuration)
#     103 scenario.set_scenario_manager(self.name)
#
# File ~/git/bptk_tutorial_internal/model-library/enterprise-digital-twin/simulation_models/enterprise_digital_twin.py:17, in EnterpriseDigitalTwin.instantiate_model(self)
#      14 self.register_agent_factory("project", lambda agent_id, model, properties: Project(agent_id, model, properties))
#      15 self.register_agent_factory("controlling", lambda agent_id, model, properties: Controlling(agent_id, model, properties))
# ---> 17 self.sd_model = EnterpriseDigitalTwinSD(self)
#
# File ~/git/bptk_tutorial_internal/model-library/enterprise-digital-twin/simulation_models/sd/enterprise_digital_twin_sd.py:33, in EnterpriseDigitalTwinSD.__init__(self, model)
#      31 cash.initialize(revenue=revenue,cost=cost)
#      32 revenue.initialize()
# ---> 33 earnings.initialize(cost=cost,revenue=revenue)
#      34 cost.initialize()
#
# File ~/git/bptk_tutorial_internal/model-library/enterprise-digital-twin/simulation_models/sd/earnings.py:22, in Earnings.initialize(self, revenue, cost)
#      19 profit = self.converter("profit")
#      21 # equations
# ---> 22 profit.equation=revenue.revenue - cost.expenses
#      24 earnings.initial_value = 0.0
#      25 earnings_in.equation=profit
#
# AttributeError: 'Revenue' object has no attribute 'revenue'

# %%
bptk.list_scenarios()
# Out:
# *** smEDT ***
# 	 two_consultants
# 	 three_consultants
# 	 base
# 	 interactive

# %%
bptk.get_scenario(scenario_manager="smEDT",scenario="three_consultants").agents
# Out:
# [<simulation_models.abm.consultant.Consultant at 0x138759820>,
#  <simulation_models.abm.consultant.Consultant at 0x1387591f0>,
#  <simulation_models.abm.consultant.Consultant at 0x138759f40>,
#  <simulation_models.abm.consultant.Consultant at 0x138759220>,
#  <simulation_models.abm.consultant.Consultant at 0x1387599a0>,
#  <simulation_models.abm.consultant.Consultant at 0x138759400>,
#  <simulation_models.abm.consultant.Consultant at 0x138759880>,
#  <simulation_models.abm.consultant.Consultant at 0x138759430>,
#  <simulation_models.abm.consultant.Consultant at 0x138759910>,
#  <simulation_models.abm.consultant.Consultant at 0x138759a90>,
#  <simulation_models.abm.controlling.Controlling at 0x138759eb0>,
#  <simulation_models.abm.project.Project at 0x138759310>,
#  <simulation_models.abm.project.Project at 0x138759070>,
#  <simulation_models.abm.project.Project at 0x138759a60>,
#  <simulation_models.abm.project.Project at 0x1387598b0>,
#  <simulation_models.abm.project.Project at 0x138759190>]

# %% [markdown]
# ## Base Scenario

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["base"],
    title="Project Lifecycle",
    agents=["project"],
    agent_states=["acquired","ready","started","fully_staffed","completed"],
    series_names={
         "smEDT_base_project_acquired" : "Acquired",
         "smEDT_base_project_ready" : "Ready",
         "smEDT_base_project_started" : "Started",
         "smEDT_base_project_fully_staffed" : "Fully Staffed",
         "smEDT_base_project_completed" : "Completed",
     }
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["base"],
    title="Consultants",
    agents=["consultant"],
    agent_states=["available","busy"],
    series_names={
         "smEDT_base_consultant_available" : "Available",
         "smEDT_base_consultant_busy" : "Busy"
     }
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["base"],
    title="Revenue",
    agents=["controlling"],
    agent_states=["active"],
    agent_properties=["revenue"],
    agent_property_types=["total"]

)

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["base"],
    title="Expenses",
    agents=["controlling"],
    agent_states=["active"],
    agent_properties=["expenses"],
    agent_property_types=["total"]

)

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["base"],
    title="Profit",
    agents=["controlling"],
    agent_states=["active"],
    agent_properties=["profit"],
    agent_property_types=["total"]

)

# %% [markdown]
# ## Two Consultants per Project Scenario

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["two_consultants"],
    title="Project Lifecycle",
    agents=["project"],
    agent_states=["acquired","ready","started","fully_staffed","completed"],
    series_names={
         "smEDT_base_project_acquired" : "Acquired",
         "smEDT_base_project_ready" : "Ready",
         "smEDT_base_project_started" : "Started",
         "smEDT_base_project_fully_staffed" : "Fully Staffed",
         "smEDT_base_project_completed" : "Completed",
     }
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["two_consultants"],
    title="Consultants",
    agents=["consultant"],
    agent_states=["available","busy"],
    series_names={
         "smEDT_base_consultant_available" : "Available",
         "smEDT_base_consultant_busy" : "Busy"
     }
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["two_consultants"],
    title="Revenue",
    agents=["controlling"],
    agent_states=["active"],
    agent_properties=["revenue"],
    agent_property_types=["total"]

)

# %% [markdown]
# ### Three Consultants per Project

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["three_consultants"],
    title="Project Lifecycle",
    agents=["project"],
    agent_states=["acquired","ready","started","fully_staffed","completed"],
    series_names={
         "smEDT_base_project_acquired" : "Acquired",
         "smEDT_base_project_ready" : "Ready",
         "smEDT_base_project_started" : "Started",
         "smEDT_base_project_fully_staffed" : "Fully Staffed",
         "smEDT_base_project_completed" : "Completed",
     }
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["three_consultants"],
    title="Consultants",
    agents=["consultant"],
    agent_states=["available","busy"],
    series_names={
         "smEDT_base_consultant_available" : "Available",
         "smEDT_base_consultant_busy" : "Busy"
     }
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["three_consultants"],
    title="Revenue",
    agents=["controlling"],
    agent_states=["active"],
    agent_properties=["revenue"],
    agent_property_types=["total"]

)

# %%
bptk.plot_scenarios(
    scenario_managers=["smEDT"],
    kind="area",
    scenarios=["three_consultants"],
    title="Accumulated Profit",
    agents=["controlling"],
    agent_states=["active"],
    agent_properties=["accumulated_profit"],
    agent_property_types=["total"]

)
