# %% [markdown]
# # CustomerAcquisition

# %%
## BPTK Package
from BPTK_Py.bptk import bptk 

bptk = bptk()

# %%
bptk.plot_scenarios(
   scenario_managers=["smCustomerAcquisition"],
    scenarios=["hereWeGo"], 
    equations=['customers'],
    title="Here We Go",
    freq="M",
    x_label="Time",
    y_label="Customers"
)

# %%
bptk.plot_scenarios(
   scenario_managers=["smCustomerAcquisition"],
    scenarios=["hereWeGo"], 
    equations=['profit'],
    title="Here We Go",
    freq="M",
    x_label="Time",
    y_label="Accumulated Profit"
)

# %%
bptk.plot_scenarios(
   scenario_managers=["smCustomerAcquisition"],
    scenarios=["serviceFlop"], 
    equations=['customers'],
    title="Service Flop",
    freq="M",
    x_label="Time",
    y_label="Customers"
)

# %%
bptk.plot_scenarios(
   scenario_managers=["smCustomerAcquisition"],
    scenarios=["serviceFlop"], 
    equations=['profit'],
    title="Service Flop",
    freq="M",
    x_label="Time",
    y_label="Accumulated Profit"
)

# %%
bptk.plot_scenarios(
   scenario_managers=["smCustomerAcquisition"],
    scenarios=["referSomeonePlease"], 
    equations=['customers'],
    title="Refer Someone, Please!",
    freq="M",
    x_label="Time",
    y_label="Customers"
)

# %%
bptk.plot_scenarios(
   scenario_managers=["smCustomerAcquisition"],
    scenarios=["referSomeonePlease"], 
    equations=['profit'],
    title="Refer Someone, Please!",
    freq="M",
    x_label="Time",
    y_label="Accumulated Profit"
)

# %%
bptk.plot_scenarios(
   scenario_managers=["smCustomerAcquisition"],
    scenarios=["rethinkAdvertising"], 
    equations=['customers'],
    title="Rethink Advertising",
    freq="M",
    x_label="Time",
    y_label="Customers"
)

# %%
bptk.plot_scenarios(
   scenario_managers=["smCustomerAcquisition"],
    scenarios=["rethinkAdvertising"], 
    equations=['profit'],
    title="Rethink Advertising",
    freq="M",
    x_label="Time",
    y_label="Accumulated Profit"
)

# %%
bptk.plot_scenarios(
   scenario_managers=["smCustomerAcquisition"],
    scenarios=["boomButBust"], 
    equations=['profit'],
    title="Boom But Bust",
    freq="M",
    x_label="Time",
    y_label="Accumulated Profit"
)
